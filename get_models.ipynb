# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import sys
print('Python version:', sys.version)
print('Pandas version:', pd.__version__)
print('Numpy version:', np.__version__)
print('Matplotlib version:', matplotlib.__version__)
plt.rcParams['font.sans-serif'] = 'STsong'
# Out:
# Python version: 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]
# Pandas version: 2.2.2
# Numpy version: 1.26.4
# Matplotlib version: 3.9.2

# %%
data=pd.read_csv('./项目二二手房数据.csv',index_col=0)
X=data.drop('租价：元/平方米/月',axis=1)
y=data['租价：元/平方米/月']

# %%
X.columns
# Out:
# Index(['街道', '朝向', '官方核验', '公寓', '独立阳台', '近地铁', '押一付一', '独立卫生间', '集中供暖',
#        '双卫生间', '精装', '随时看房', '拎包入住', '新上', '是否月租', '室数', '厅数', '卫数', '总楼层数',
#        '租赁方式_合租', '租赁方式_整租', '租赁方式_第三人民医院家属院 3室2厅 南/北', '区_临潼', '区_新城区',
#        '区_未央', '区_灞桥', '区_碑林', '区_莲湖', '区_蓝田', '区_西咸新区（西安）', '区_鄠邑区', '区_长安',
#        '区_雁塔', '区_高陵', '楼层高低_中楼层', '楼层高低_低楼层', '楼层高低_地下室', '楼层高低_高楼层'],
#       dtype='object')

# %%
X

# %%
X.describe()
# Out:
#                  街道            朝向          官方核验            公寓          独立阳台  \
# count  84797.000000  84797.000000  84797.000000  84797.000000  84797.000000
# mean      21.944892     27.064495      0.312075      0.312075      0.103636
# std       13.180833      9.847494      0.463343      0.463343      0.304789
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       10.000000     30.000000      0.000000      0.000000      0.000000
# 50%       19.000000     30.000000      0.000000      0.000000      0.000000
# 75%       33.000000     31.000000      1.000000      1.000000      0.000000
# max       49.000000     47.000000      1.000000      1.000000      1.000000
#
#                 近地铁          押一付一         独立卫生间         集中供暖          双卫生间  \
# count  84797.000000  84797.000000  84797.000000  84797.00000  84797.000000
# mean       0.460936      0.155678      0.036204      0.73604      0.199818
# ...

# %%
X.head()
# Out:
#    街道  朝向  官方核验  公寓  独立阳台  近地铁  押一付一  独立卫生间  集中供暖  双卫生间  ...   区_蓝田  \
# 0   7  10     0   0     0    0     0      0     1     0  ...  False
# 1  44  30     1   1     0    0     0      1     1     0  ...  False
# 2  44  31     0   0     0    1     0      0     1     0  ...  False
# 3   7  30     1   1     0    1     1      0     1     0  ...  False
# 4  19  30     0   0     0    0     0      0     1     1  ...  False
#
#    区_西咸新区（西安）  区_鄠邑区   区_长安   区_雁塔   区_高陵  楼层高低_中楼层  楼层高低_低楼层  楼层高低_地下室  \
# 0       False  False  False   True  False     False     False     False
# 1       False  False  False   True  False      True     False     False
# 2       False  False  False   True  False     False     False     False
# 3       False  False  False   True  False     False     False     False
# 4       False  False   True  False  False     False      True     False
#
#    楼层高低_高楼层
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
#
# [5 rows x 38 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,  test_size=0.3, random_state=1210)

# %%
from sklearn.tree import DecisionTreeRegressor

reg_data = DecisionTreeRegressor(max_depth=17,
                                 min_samples_leaf=2,
                                 min_samples_split=8,
                                 splitter='random',
                                 random_state=1210)
reg_data.fit(X,y)
# Out:
# DecisionTreeRegressor(max_depth=17, min_samples_leaf=2, min_samples_split=8,
#                       random_state=1210, splitter='random')

# %%
import joblib
joblib.dump(reg_data,'models/DTR.pkl')
# Out:
# ['models/DTR.pkl']

# %%
from sklearn.ensemble import RandomForestRegressor

rfr_best = RandomForestRegressor(n_estimators=700,
                                 max_depth=19,
                             max_features=11,
                            min_samples_split=2,
                             random_state=1210,
                            min_samples_leaf= 2
                           )
rfr_best.fit(X_train_important,y_train)
